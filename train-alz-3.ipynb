# %%
import os 
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import keras 
from keras.callbacks import EarlyStopping,ModelCheckpoint
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from tqdm import tqdm
from imblearn.over_sampling import SMOTE
# Out:
# 2024-05-20 07:29:35.986988: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-20 07:29:35.987108: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-20 07:29:36.136330: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
images = []
labels = []
for subfolder in tqdm(os.listdir('/kaggle/input/ad-disease/train')):
    subfolder_path = os.path.join('/kaggle/input/ad-disease/train', subfolder)
    for folder in os.listdir(subfolder_path):
        subfolder_path2=os.path.join(subfolder_path,folder)
        for image_filename in os.listdir(subfolder_path2):
            image_path = os.path.join(subfolder_path2, image_filename)
            images.append(image_path)
            labels.append(folder)
df = pd.DataFrame({'image': images, 'label': labels})
df
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  1.66it/s]
#                                                   image             label
# 0     /kaggle/input/ad-disease/train/train/ModerateD...  ModerateDemented
# 1     /kaggle/input/ad-disease/train/train/ModerateD...  ModerateDemented
# 2     /kaggle/input/ad-disease/train/train/ModerateD...  ModerateDemented
# 3     /kaggle/input/ad-disease/train/train/ModerateD...  ModerateDemented
# 4     /kaggle/input/ad-disease/train/train/ModerateD...  ModerateDemented
# ...                                                 ...               ...
# 5116  /kaggle/input/ad-disease/train/train/MildDemen...      MildDemented
# 5117  /kaggle/input/ad-disease/train/train/MildDemen...      MildDemented
# 5118  /kaggle/input/ad-disease/train/train/MildDemen...      MildDemented
# 5119  /kaggle/input/ad-disease/train/train/MildDemen...      MildDemented
# 5120  /kaggle/input/ad-disease/train/train/MildDemen...      MildDemented
#
# [5121 rows x 2 columns]

# %%
plt.figure(figsize=(5, 5))
class_counts = df['label'].value_counts()
labels = class_counts.index
sizes = class_counts.values

plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('Set1'))
plt.title('Distribution of Classes', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(50,50))
for n,i in enumerate(np.random.randint(0,len(df),20)):
    plt.subplot(10,5,n+1)
    img=cv2.imread(df.image[i])
    img=cv2.resize(img,(224,224))
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.axis('off')
    plt.title(df.label[i],fontsize=25)

# %%
class_num=np.sort(['MildDemented','ModerateDemented','NonDemented','VeryMildDemented'])
class_num
# Out:
# array(['MildDemented', 'ModerateDemented', 'NonDemented',
#        'VeryMildDemented'], dtype='<U16')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
Size=(128,128)
work_dr = ImageDataGenerator(
    rescale = 1./255
)
train_data_gen = work_dr.flow_from_dataframe(df,x_col='image',y_col='label', target_size=Size, batch_size=6500, shuffle=False)
# Out:
# Found 5121 validated image filenames belonging to 4 classes.

# %%
# Get the first batch of data and labels
train_data, train_labels = train_data_gen[0]
for i in range(len(train_data_gen)):
    train_data, train_labels = train_data_gen[i]

# %%
class_num=np.sort(['MildDemented','ModerateDemented','NonDemented','VeryMildDemented'])
class_num
# Out:
# array(['MildDemented', 'ModerateDemented', 'NonDemented',
#        'VeryMildDemented'], dtype='<U16')

# %%
sm = SMOTE(random_state=42)
train_data, train_labels = sm.fit_resample(train_data.reshape(-1, 128 * 128 * 3), train_labels)
train_data = train_data.reshape(-1, 128,128, 3)
print(train_data.shape, train_labels.shape)
# Out:
# (10240, 128, 128, 3) (10240, 4)

# %%
labels=[class_num[i] for i in np.argmax(train_labels,axis=1) ]
plt.figure(figsize=(6,4))
ax = sns.countplot(x=labels,palette='Set1')
ax.set_xlabel("Class",fontsize=20)
ax.set_ylabel("Count",fontsize=20)
plt.title('The Number Of Samples For Each Class',fontsize=20)
plt.grid(True)
plt.xticks(rotation=45)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
X_train, X_test1, y_train, y_test1 = train_test_split(train_data,train_labels, test_size=0.3, random_state=42,shuffle=True,stratify=train_labels)
X_val, X_test, y_val, y_test = train_test_split(X_test1,y_test1, test_size=0.5, random_state=42,shuffle=True,stratify=y_test1)
print('X_train shape is ' , X_train.shape)
print('X_test shape is ' , X_test.shape)
print('X_val shape is ' , X_val.shape)
print('y_train shape is ' , y_train.shape)
print('y_test shape is ' , y_test.shape)
print('y_val shape is ' , y_val.shape)
# Out:
# X_train shape is  (7168, 128, 128, 3)
# X_test shape is  (1536, 128, 128, 3)
# X_val shape is  (1536, 128, 128, 3)
# y_train shape is  (7168, 4)
# y_test shape is  (1536, 4)
# y_val shape is  (1536, 4)

# %%
from keras.layers import Conv2D,Flatten,Dense,Dropout,BatchNormalization,MaxPooling2D

# %%
from keras.models import Sequential

# %%
model = Sequential()

model.add(Conv2D(32,kernel_size =(2,2),input_shape = (128,128,3),padding = 'Same'))
model.add(Conv2D(32,kernel_size =(2,2),activation='relu',padding = 'Same'))

model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64,kernel_size =(2,2),activation='relu',padding = 'Same'))
model.add(Conv2D(64,kernel_size =(2,2),activation='relu',padding = 'Same'))

model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides = (2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
          
model.add(Dense(512,activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(4,activation='softmax'))
          
model.compile(loss = 'categorical_crossentropy',optimizer = 'Adamax',metrics=['accuracy'])
          
print(model.summary())
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 128, 32)   │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 64)     │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 64, 64, 64)     │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 65536)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    33,554,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         2,052 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,586,628 (128.12 MB)
#  Trainable params: 33,586,436 (128.12 MB)
#  Non-trainable params: 192 (768.00 B)
# None

# %%
X_train.shape
# Out:
# (7168, 128, 128, 3)

# %%
X_test.shape
# Out:
# (1536, 128, 128, 3)

# %%
history = model.fit(X_train,y_train,epochs = 30,batch_size=10,verbose=1,validation_data=(X_test,y_test))
# Out:
# Epoch 1/30
#   6/717 ━━━━━━━━━━━━━━━━━━━━ 17s 25ms/step - accuracy: 0.2047 - loss: 42.9834
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1716190246.961380      85 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1716190246.981709      85 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4589 - loss: 7.6720
# W0000 00:00:1716190267.530707      85 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1716190268.918268      86 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 35s 33ms/step - accuracy: 0.4590 - loss: 7.6649 - val_accuracy: 0.5859 - val_loss: 0.9326
# Epoch 2/30
#   7/717 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.5671 - loss: 0.7925
# W0000 00:00:1716190270.704101      86 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.5991 - loss: 0.7972 - val_accuracy: 0.7715 - val_loss: 0.6217
# Epoch 3/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.6477 - loss: 0.6945 - val_accuracy: 0.7773 - val_loss: 0.5244
# Epoch 4/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.7118 - loss: 0.5787 - val_accuracy: 0.8503 - val_loss: 0.3708
# Epoch 5/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.7634 - loss: 0.4843 - val_accuracy: 0.8678 - val_loss: 0.3396
# Epoch 6/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7939 - loss: 0.4297 - val_accuracy: 0.8548 - val_loss: 0.3267
# Epoch 7/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.8179 - loss: 0.3826 - val_accuracy: 0.9193 - val_loss: 0.2138
# Epoch 8/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.8752 - loss: 0.2804 - val_accuracy: 0.9010 - val_loss: 0.2002
# Epoch 9/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.8983 - loss: 0.2255 - val_accuracy: 0.9707 - val_loss: 0.0822
# Epoch 10/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9237 - loss: 0.1878 - val_accuracy: 0.9746 - val_loss: 0.0685
# Epoch 11/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9417 - loss: 0.1350 - val_accuracy: 0.9746 - val_loss: 0.0689
# Epoch 12/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9492 - loss: 0.1211 - val_accuracy: 0.9714 - val_loss: 0.0740
# Epoch 13/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9615 - loss: 0.0988 - val_accuracy: 0.9850 - val_loss: 0.0485
# Epoch 14/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9679 - loss: 0.0787 - val_accuracy: 0.9922 - val_loss: 0.0249
# Epoch 15/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9722 - loss: 0.0699 - val_accuracy: 0.9896 - val_loss: 0.0339
# Epoch 16/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9780 - loss: 0.0548 - val_accuracy: 0.9889 - val_loss: 0.0257
# Epoch 17/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9758 - loss: 0.0719 - val_accuracy: 0.9883 - val_loss: 0.0269
# Epoch 18/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9790 - loss: 0.0541 - val_accuracy: 0.9967 - val_loss: 0.0147
# Epoch 19/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9840 - loss: 0.0378 - val_accuracy: 0.9941 - val_loss: 0.0155
# Epoch 20/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9872 - loss: 0.0321 - val_accuracy: 0.9935 - val_loss: 0.0204
# Epoch 21/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9885 - loss: 0.0319 - val_accuracy: 0.9896 - val_loss: 0.0255
# Epoch 22/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9911 - loss: 0.0249 - val_accuracy: 0.9915 - val_loss: 0.0294
# Epoch 23/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9881 - loss: 0.0303 - val_accuracy: 0.9948 - val_loss: 0.0167
# Epoch 24/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9928 - loss: 0.0287 - val_accuracy: 0.9883 - val_loss: 0.0413
# Epoch 25/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9904 - loss: 0.0283 - val_accuracy: 0.9974 - val_loss: 0.0099
# Epoch 26/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9884 - loss: 0.0304 - val_accuracy: 0.9961 - val_loss: 0.0077
# Epoch 27/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9919 - loss: 0.0233 - val_accuracy: 0.9974 - val_loss: 0.0077
# Epoch 28/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9925 - loss: 0.0230 - val_accuracy: 0.9935 - val_loss: 0.0265
# Epoch 29/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9932 - loss: 0.0180 - val_accuracy: 0.9909 - val_loss: 0.0232
# Epoch 30/30
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9938 - loss: 0.0166 - val_accuracy: 0.9974 - val_loss: 0.0098

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Loss')
plt.ylabel('Epoch')
plt.legend(['Test','Validation'],loc='upper right')
plt.show()

# %%
score, acc= model.evaluate(X_test,y_test)
print('Test Loss =', score)
print('Test Accuracy =', acc)
# Out:
# 21/48 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9967 - loss: 0.0106
# W0000 00:00:1716190685.904244      85 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9967 - loss: 0.0112
# Test Loss = 0.00978915486484766
# Test Accuracy = 0.9973958134651184

# %%
y_pred = np.argmax(model.predict(X_test),axis=1)
print(np.mean(y_pred == np.argmax(y_test,axis=1)))
# Out:
# 21/48 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# W0000 00:00:1716190688.716423      86 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 0.9973958333333334

# %%
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
confusion_mtx = confusion_matrix(np.argmax(y_test, axis=1), y_pred_classes)
print("Confusion Matrix:\n", confusion_mtx)
# Out:
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Confusion Matrix:
#  [[384   0   0   0]
#  [  0 384   0   0]
#  [  1   0 381   2]
#  [  0   0   1 383]]

# %%
from sklearn.metrics import f1_score

# %%
f1_scores = f1_score(np.argmax(y_test, axis=1), y_pred_classes, average='weighted')
print("F1 Score:", f1_scores)
# Out:
# F1 Score: 0.9973941268542443

# %%
from sklearn.metrics import precision_score
precision_scores = precision_score(np.argmax(y_test, axis=1), y_pred_classes, average='weighted')
print("Precision:", precision_scores)
# Out:
# Precision: 0.9973974977901681

# %%
from sklearn.metrics import recall_score
recall_scores = recall_score(np.argmax(y_test, axis=1), y_pred_classes, average='weighted')
print("Recall:", recall_scores)
# Out:
# Recall: 0.9973958333333334
